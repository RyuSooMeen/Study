# %%
import pandas as pd
import numpy as np
df = pd.read_csv("https://raw.githubusercontent.com/Datamanim/datarepo/main/youtube/youtube.csv",index_col=0)
df.head()
# Out:
#                                                title             channelTitle  \
# 0                                          [신병] 물자창고                      장삐쭈
# 1   RAIN(비) - 나로 바꾸자 Switch to me (duet with JYP) MV  RAIN's Official Channel
# 2       2020년 제야의 종 온라인 타종행사 | 보신각 현장 행사는 진행하지 않습니다.              서울시 · Seoul
# 3                                       고기남자의 칠면조 파티             고기남자 MeatMan
# 4  골목 3mc를 분노하게 만든 마음고생이 심했을 공릉 백반집 사장님의 푸념?! [예능...                    스브스밥집
#
#    categoryId  view_count  likes  dislikes  comment_count  \
# 0          23     1893473  38249       730           8595
# 1          10     2600864      0         0          20129
# 2          29      347049   3564       120            178
# 3          26      528458  15372       280           3470
# 4          24      494904   3918       111           3142
#
#                   channelId trending_date2
# 0  UChbE5OZQ6dRHECsX0tEPEZQ     2021-01-01
# 1  UCxXgIeE5hxWxHG6dz9Scg2w     2021-01-01
# ...

# %% [markdown]
# ## Question 1
# #### 인기동영상 제작횟수가 많은 채널 상위 10개명을 출력하라 (날짜기준, 중복포함)

# %%
answer1 =list(df.loc[df.channelId.isin(df.channelId.value_counts().head(10).index)].channelTitle.unique())
print(answer1)
# Out:
# ['장삐쭈', '총몇명', '파뿌리', '짤툰', '런닝맨 - 스브스 공식 채널', '엠뚜루마뚜루 : MBC 공식 종합 채널', 'SPOTV', '채널 십오야', '이과장', 'BANGTANTV']

# %% [markdown]
# ## Question 2
# #### 논란으로 인기동영상이 된 케이스를 확인하고 싶다. dislikes수가 like 수보다 높은 동영상을 제작한 채널을 모두 출력하라

# %%
answer2 = list(df[df.dislikes > df.likes].channelTitle.unique())
#answer2 = list(df.loc[df.likes < df.dislikes].channelTitle.unique())
print(answer2)
# Out:
# ['핫도그TV', 'ASMR 애정TV', '하얀트리HayanTree', '양팡 YangPang', '철구형 (CHULTUBE)', '왜냐맨하우스', '(MUTUBE)와꾸대장봉준', '오메킴TV', '육지담', 'MapleStory_KR', 'ROAD FIGHTING CHAMPIONSHIP', '사나이 김기훈', '나혼자산다 STUDIO', 'Gen.G esports']

# %% [markdown]
# ## Question 3
# #### 채널명을 바꾼 케이스가 있는지 확인하고 싶다. channelId의 경우 고유값이므로 이를 통해 채널명을 한번이라도 바꾼 채널의 갯수를 구하여라

# %%
change = df[['channelTitle','channelId']].drop_duplicates().channelId.value_counts()
target = change[change>1]
print(len(target))
# Out:
# 71

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datamanim/pandas/main/under5MortalityRate.csv')

# %%
df
# Out:
#           Location  Period                                          Indicator  \
# 0      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 1      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 2      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 3      Afghanistan    2018  Under-five mortality rate (probability of dyin...
# 4      Afghanistan    2018  Under-five mortality rate (probability of dyin...
# ...            ...     ...                                                ...
# 29994  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29995  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29996  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29997  Timor-Leste    2001  Under-five mortality rate (probability of dyin...
# 29998  Timor-Leste    2001  Under-five mortality rate (probability of dyin...
#
# ...

# %%
df['First Tooltip'] = df['First Tooltip'].map(lambda x: float(x.split("[")[0]))

df
# Out:
#           Location  Period                                          Indicator  \
# 0      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 1      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 2      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 3      Afghanistan    2018  Under-five mortality rate (probability of dyin...
# 4      Afghanistan    2018  Under-five mortality rate (probability of dyin...
# ...            ...     ...                                                ...
# 29994  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29995  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29996  Timor-Leste    2002  Under-five mortality rate (probability of dyin...
# 29997  Timor-Leste    2001  Under-five mortality rate (probability of dyin...
# 29998  Timor-Leste    2001  Under-five mortality rate (probability of dyin...
#
#              Dim1  First Tooltip
# ...

# %%
df[(df['Period'] >= 2015) & (df['Dim1'] == 'Both sexes')]
# Out:
#           Location  Period                                          Indicator  \
# 0      Afghanistan    2019  Under-five mortality rate (probability of dyin...
# 3      Afghanistan    2018  Under-five mortality rate (probability of dyin...
# 6      Afghanistan    2017  Under-five mortality rate (probability of dyin...
# 9      Afghanistan    2016  Under-five mortality rate (probability of dyin...
# 12     Afghanistan    2015  Under-five mortality rate (probability of dyin...
# ...            ...     ...                                                ...
# 29943  Timor-Leste    2019  Under-five mortality rate (probability of dyin...
# 29946  Timor-Leste    2018  Under-five mortality rate (probability of dyin...
# 29949  Timor-Leste    2017  Under-five mortality rate (probability of dyin...
# 29952  Timor-Leste    2016  Under-five mortality rate (probability of dyin...
# 29955  Timor-Leste    2015  Under-five mortality rate (probability of dyin...
#
#              Dim1  First Tooltip
# ...

# %%
a = df[(df['Period'] >= 2015) & (df['Dim1'] == 'Both sexes')]
a.pivot(index ='Location',columns = 'Period',values = 'First Tooltip')
# Out:
# Period                                      2015   2016   2017   2018   2019
# Location
# Afghanistan                                70.44  67.57  64.94  62.54  60.27
# Albania                                     9.57   9.42   9.42   9.53   9.68
# Algeria                                    25.18  24.79  24.32  23.81  23.26
# Andorra                                     3.53   3.37   3.22   3.09   2.97
# Angola                                     88.20  84.21  80.62  77.67  74.69
# ...                                          ...    ...    ...    ...    ...
# Syrian Arab Republic                       23.18  23.27  22.97  22.11  21.53
# Tajikistan                                 37.75  36.82  35.81  34.80  33.78
# Thailand                                   10.80  10.32   9.86   9.42   9.01
# The former Yugoslav Republic of Macedonia  12.97  11.97   9.94   7.83   6.12
# Timor-Leste                                50.76  49.01  47.27  45.62  44.22
#
# [172 rows x 5 columns]

# %%
df.pivot_table(values='First Tooltip', columns ='Period',index= 'Dim1', aggfunc = 'mean')
# Out:
# Period            1950        1951        1952        1953        1954  \
# Dim1
# Both sexes  147.700816  155.537544  157.811094  156.147206  154.539857
# Female      140.909796  149.210175  151.516094  150.250882  148.688286
# Male        154.151224  161.538246  163.760781  161.742059  160.081000
#
# Period            1955        1956        1957        1958        1959  ...  \
# Dim1                                                                    ...
# Both sexes  155.797179  159.241163  156.170114  150.813222  150.574000  ...
# Female      149.843205  153.048721  149.988295  144.719667  144.451474  ...
# Male        161.456923  165.089535  162.015000  156.573556  156.375053  ...
#
# Period           2010       2011       2012       2013       2014       2015  \
# Dim1
# Both sexes  37.718488  35.573663  34.290988  33.099360  32.053314  31.012093
# Female      34.953023  32.877616  31.654070  30.521337  29.524302  28.544360
# ...
